# %% [markdown]
# # ☁️ Antigravity Sovereign Colab Worker
# This notebook establishes the T4/A100 Cloud GPU connection back to the M1 Max VFS (Google Drive) for asynchronous refactoring and heavy model inference.

# %%
from google.colab import drive

drive.mount("/content/drive")

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
import os

# Mount the same Google Drive account that your local Mac's Google Drive sync app uses
drive.mount("/content/drive")

# Ensure the IPC directories exist
IPC_DIR = "/content/drive/MyDrive/Antigravity_IPC"
os.makedirs(f"{IPC_DIR}/inbox", exist_ok=True)
os.makedirs(f"{IPC_DIR}/outbox", exist_ok=True)
print(f"✅ VFS Mounted successfully at {IPC_DIR}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ VFS Mounted successfully at /content/drive/MyDrive/Antigravity_IPC

# %%
# !pip install -qU google-genai pydantic

# %%
import os
import time
import json
import traceback
from google import genai

# IMPORTANT: Paste your actual Gemini API key below before running this cell
os.environ["GEMINI_API_KEY"] = "AIzaSyBAJuLUQwDtMVSM5YPHpEaRVLXwuRuH7UI"
client = genai.Client()

IPC_DIR = "/content/drive/MyDrive/Antigravity_IPC"
print("☁️ Sovereign Cloud GPU Worker Online. Polling VFS for Great Refactor Payloads...")

while True:
    try:
        # Poll the inbox for new Python payloads
        tasks = [f for f in os.listdir(f"{IPC_DIR}/inbox") if f.endswith(".py")]
        for task in tasks:
            inbox_path = f"{IPC_DIR}/inbox/{task}"
            outbox_path = f"{IPC_DIR}/outbox/{task.replace('.py', '.json')}"
            tmp_outbox = outbox_path + ".tmp"

            print(f"📦 [Colab] Picked up task: {task}")

            try:
                # Execute the structural refactor payload sent from the Mac
                namespace = {}
                exec(open(inbox_path).read(), namespace)

                output = {"status": "success", "data": str(namespace.get("RESULT", "Done"))}
                print(f"✅ [Colab] Finished task: {task}")
            except Exception as e:
                output = {"status": "error", "traceback": traceback.format_exc()}
                print(f"❌ [Colab] Failed task: {task} - {e}")

            # ATOMIC WRITE: Prevents the Mac from reading a half-synced JSON file
            with open(tmp_outbox, "w") as f:
                json.dump(output, f)
            os.rename(tmp_outbox, outbox_path)

            # Clean up the inbox payload
            os.remove(inbox_path)

        # Poll every 3 seconds to avoid aggressively rate-limiting Google Drive
        time.sleep(3)

    except KeyboardInterrupt:
        print("\n🛑 Colab Worker Safely Terminated.")
        break
    except Exception as general_e:
        print(f"⚠️ Polling loop hiccup: {general_e}")
        time.sleep(5)
# Out:
# ☁️ Sovereign Cloud GPU Worker Online. Polling VFS for Great Refactor Payloads...
